# %% [markdown]
# # Video Data EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import cv2
import datetime
import numpy as np

# %%
workspace_path = "/mount/data"

# %%
url_dataset = pd.read_csv(workspace_path + '/creative_commons_youtube_videos.csv')
url_dataset.head()
# Out:
#       video_id                           url  \
# 0  67OIlq2oMt0  https://youtu.be/67OIlq2oMt0
# 1  EUcMuUBMYJc  https://youtu.be/EUcMuUBMYJc
# 2  dpSuygz7ZmA  https://youtu.be/dpSuygz7ZmA
# 3  jfPzlFLEuKk  https://youtu.be/jfPzlFLEuKk
# 4  xGasapMoy4I  https://youtu.be/xGasapMoy4I
#
#                                                title         license  \
# 0  Hawaiian Islands Humpback Whale National Marin...  creativeCommon
# 1  Tagging expedition: revealing the delicate nur...  creativeCommon
# 2  Your Earth Is Blue: Disentangling a Humpback W...  creativeCommon
# 3  Humpback Whale || Description, Characteristics...  creativeCommon
# 4                Your Earth Is Blue: Humpback Whales  creativeCommon
#
#    relevant   renamed_title
# 0      True  video_0000.mp4
# 1      True  video_0001.mp4
# 2      True  video_0002.mp4
# 3      True  video_0003.mp4
# 4      True  video_0004.mp4

# %%
#get names of all videos that WERE downloaded
succesful_downloads = []

for video in glob.glob(workspace_path + '/videos/*.mp4'):
    title = video.replace(workspace_path + '/videos/', '')
    succesful_downloads.append(title)
    
succesful_downloads[0:5]
# Out:
# ['video_0264.mp4',
#  'video_0041.mp4',
#  'video_0094.mp4',
#  'video_0267.mp4',
#  'video_0043.mp4']

# %%
#check class labels of successful downloads
downloads_df = url_dataset.loc[url_dataset['renamed_title'].isin(succesful_downloads)]

print(downloads_df.relevant.value_counts(), '\n')
plt.style.use('seaborn-colorblind')
ax = downloads_df.relevant.value_counts().plot(kind='barh', \
                                               title='Count of Relevant Labels for Succesful Video Downloads', \
                                               figsize=(8,6));

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# Out:
# True     186
# False    182
# Name: relevant, dtype: int64

# %% [markdown]
# `Class counts are roughly equal, though slightly less (-15ish) videos of original dataset`

# %%
# downloads_df = downloads_df.drop(columns=['Unnamed: 0'])
# downloads_df
# Out:
#         video_id                           url  \
# 0    67OIlq2oMt0  https://youtu.be/67OIlq2oMt0
# 1    EUcMuUBMYJc  https://youtu.be/EUcMuUBMYJc
# 2    dpSuygz7ZmA  https://youtu.be/dpSuygz7ZmA
# 3    jfPzlFLEuKk  https://youtu.be/jfPzlFLEuKk
# 4    xGasapMoy4I  https://youtu.be/xGasapMoy4I
# ..           ...                           ...
# 363  K1RzTZI9p5U  https://youtu.be/K1RzTZI9p5U
# 364  XIhVygewzsM  https://youtu.be/XIhVygewzsM
# 365  nYGZBz5iqe8  https://youtu.be/nYGZBz5iqe8
# 366  uL8pTh8exNI  https://youtu.be/uL8pTh8exNI
# 367  NG6uz2OTLUE  https://youtu.be/NG6uz2OTLUE
#
#                                                  title         license  \
# 0    Hawaiian Islands Humpback Whale National Marin...  creativeCommon
# 1    Tagging expedition: revealing the delicate nur...  creativeCommon
# 2    Your Earth Is Blue: Disentangling a Humpback W...  creativeCommon
# 3    Humpback Whale || Description, Characteristics...  creativeCommon
# 4                  Your Earth Is Blue: Humpback Whales  creativeCommon
# ..                                                 ...             ...
# 363  El Secreto del Sueño: Un mito aborigen austral...  creativeCommon
# 364           The World&#39;s Strangest Capital Cities  creativeCommon
# 365  #HealyHustle | The Elephant Story - What do El...  creativeCommon
# 366   하와이 캠핑 빅아일랜드 스펜서 비치파크 (Feat. 마할로의 시크릿 비치도 공개합니다)  creativeCommon
# 367     Sammy&#39;s Science House 11 3 2020 2 25 44 PM  creativeCommon
#
#      relevant   renamed_title
# 0        True  video_0000.mp4
# 1        True  video_0001.mp4
# 2        True  video_0002.mp4
# 3        True  video_0003.mp4
# 4        True  video_0004.mp4
# ..        ...             ...
# 363     False  video_0425.mp4
# 364     False  video_0427.mp4
# 365     False  video_0428.mp4
# 366     False  video_0429.mp4
# 367     False  video_0430.mp4
#
# [368 rows x 6 columns]

# %%
# downloads_df.to_csv(workspace_path + '/downloaded_videos.csv', index=False)
# downloads_df.to_csv('/workspace/youtube-humpback-whale-classifier/data/downloaded_videos.csv', index=False)

# %% [markdown]
# ## Full-length Video Durations

# %%
#the df of the videos that were actually downloaded into the workspace
downloads_df = pd.read_csv(workspace_path + '/downloaded_videos.csv')
downloads_df.head()
# Out:
#       video_id                           url  \
# 0  67OIlq2oMt0  https://youtu.be/67OIlq2oMt0
# 1  EUcMuUBMYJc  https://youtu.be/EUcMuUBMYJc
# 2  dpSuygz7ZmA  https://youtu.be/dpSuygz7ZmA
# 3  jfPzlFLEuKk  https://youtu.be/jfPzlFLEuKk
# 4  xGasapMoy4I  https://youtu.be/xGasapMoy4I
#
#                                                title         license  \
# 0  Hawaiian Islands Humpback Whale National Marin...  creativeCommon
# 1  Tagging expedition: revealing the delicate nur...  creativeCommon
# 2  Your Earth Is Blue: Disentangling a Humpback W...  creativeCommon
# 3  Humpback Whale || Description, Characteristics...  creativeCommon
# 4                Your Earth Is Blue: Humpback Whales  creativeCommon
#
#    relevant   renamed_title  clip_start  clip_end  duration  frames_collected  \
# 0      True  video_0000.mp4          10        25     266.0             361.0
# 1      True  video_0001.mp4          44        59     269.0             360.0
# 2      True  video_0002.mp4           5        20     102.0             361.0
# 3      True  video_0003.mp4         160       175     238.0             450.0
# 4      True  video_0004.mp4           0        15      83.0             451.0
#
#    frames_reported  frames_reported_decord
# 0            473.0                   473.0
# 1            441.0                   441.0
# 2            398.0                   398.0
# 3            456.0                   456.0
# 4            451.0                   451.0

# %%
def get_num_video_frames(video_title, clips=False):
    if clips == False:
        data = cv2.VideoCapture(workspace_path + '/videos/' + video_title)
    else:
        data = cv2.VideoCapture(workspace_path + '/video_clips/' + video_title)
        
    return data.get(cv2.CAP_PROP_FRAME_COUNT)
    
def get_video_duration(video_title, silent = True, clips=False):

    #get video
    if clips == False:
        data = cv2.VideoCapture(workspace_path + '/videos/' + video_title)
    else:
        data = cv2.VideoCapture(workspace_path + '/video_clips/' + video_title)
        
    # count the number of frames
    frames = data.get(cv2.CAP_PROP_FRAME_COUNT)
    fps = int(data.get(cv2.CAP_PROP_FPS))

    # calculate duration of the video
    seconds = int(frames / fps)
    video_time = str(datetime.timedelta(seconds=seconds))

    if silent == False:
        print("duration in seconds:", seconds)
        print("video time:", video_time)
    
    return seconds, video_time

# %%
#get durations for videos that successfully downloaded
video_duration_seconds = []
video_duration_times = []
video_frame_counts = []

for video in downloads_df.renamed_title:
    frames = get_num_video_frames(video)
    seconds, video_time = get_video_duration(video)
    video_duration_seconds.append(seconds)
    video_duration_times.append(video_time)
    video_frame_counts.append(frames)

print('Done collection video duration info.')
# Out:
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x6689080] Unknown projection type: ytmp
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x6689080] Unknown projection type: ytmp
# [av1 @ 0x6627ec0] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x6627ec0] Failed to get pixel format.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x6627ec0] Failed to get pixel format.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] Missing Sequence Header.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] video_get_buffer: image parameters invalid
# [av1 @ 0x6627ec0] get_buffer() failed
# [av1 @ 0x6627ec0] thread_get_buffer() failed
# [av1 @ 0x6627ec0] Failed to allocate space for current frame.
# [av1 @ 0x6627ec0] Get current frame error
# [av1 @ 0x6627ec0] Failed to get reference frame.
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x6619e40] Unknown projection type: ytmp
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x6619e40] Unknown projection type: ytmp
# [av1 @ 0x66302c0] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x66302c0] Failed to get pixel format.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# ...
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x66302c0] Failed to get pixel format.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] Missing Sequence Header.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# [av1 @ 0x66302c0] Failed to get reference frame.
# [av1 @ 0x66302c0] video_get_buffer: image parameters invalid
# [av1 @ 0x66302c0] get_buffer() failed
# [av1 @ 0x66302c0] thread_get_buffer() failed
# [av1 @ 0x66302c0] Failed to allocate space for current frame.
# [av1 @ 0x66302c0] Get current frame error
# Done collection video duration info.

# %%
#scatterplot of video durations in seconds
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
plt.scatter([i for i in range(0, len(downloads_df.renamed_title))], video_duration_seconds)
plt.xlabel('Video')
plt.ylabel('Duration (seconds)')
plt.title('Video Durations in Seconds of Successful Downloads');

# %%
#histogram of video durations in seconds
print('Mean Video Duration (seconds):   ', np.array(video_duration_seconds).mean())
print('Median Video Duration (seconds): ', np.median(np.array(video_duration_seconds)))
print('Max Video Duration (seconds):    ', np.array(video_duration_seconds).max())
print('Min Video Duration (seconds):    ', np.array(video_duration_seconds).min(), '\n')

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
plt.hist(video_duration_seconds)
plt.xlabel('Duration(seconds)')
plt.ylabel('Count')
plt.title('Video Durations in Seconds of Successful Downloads');
# Out:
# Mean Video Duration (seconds):    230.51902173913044
# Median Video Duration (seconds):  100.0
# Max Video Duration (seconds):     4572
# Min Video Duration (seconds):     4

# %%
#histogram of video frames 
print('Mean Num of Video Frames:   ', np.array(video_frame_counts).mean())
print('Median Num of Video Frames: ', np.median(np.array(video_frame_counts)))
print('Max Num of Video Frames:    ', np.array(video_frame_counts).max())
print('Min Num of Video Frames:    ', np.array(video_frame_counts).min(), '\n')

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
plt.hist(video_frame_counts)
plt.xlabel('Number of Video Frames')
plt.ylabel('Count')
plt.title('Number of Video Frames in Successful Video Downloads');
# Out:
# Mean Num of Video Frames:    7114.809782608696
# Median Num of Video Frames:  2959.5
# Max Num of Video Frames:     114319.0
# Min Num of Video Frames:     42.0

# %% [markdown]
# Decision: Use the Median number of frames available in our dataset to cut down videos. This means we should collect `2960 frames from each video`, and pad those that don't meet this count by replicating the middle frame.

# %% [markdown]
# Note: Since we did not identify and narrow down videos to occurence intervals, the possibility that the extracted frames skip over the humpback whale encounter exists. Additionally, there might be more noise included if the whale encounter in the relevant videos only makes up a small portion of the overall video.

# %% [markdown]
# # Video Clip Durations

# %%
#load data of successful downloads
downloads_df = pd.read_csv(workspace_path + '/downloaded_videos.csv')
downloads_df.head()
# Out:
#       video_id                           url  \
# 0  67OIlq2oMt0  https://youtu.be/67OIlq2oMt0
# 1  EUcMuUBMYJc  https://youtu.be/EUcMuUBMYJc
# 2  dpSuygz7ZmA  https://youtu.be/dpSuygz7ZmA
# 3  jfPzlFLEuKk  https://youtu.be/jfPzlFLEuKk
# 4  xGasapMoy4I  https://youtu.be/xGasapMoy4I
#
#                                                title         license  \
# 0  Hawaiian Islands Humpback Whale National Marin...  creativeCommon
# 1  Tagging expedition: revealing the delicate nur...  creativeCommon
# 2  Your Earth Is Blue: Disentangling a Humpback W...  creativeCommon
# 3  Humpback Whale || Description, Characteristics...  creativeCommon
# 4                Your Earth Is Blue: Humpback Whales  creativeCommon
#
#    relevant   renamed_title  clip_start  clip_end  duration
# 0      True  video_0000.mp4          10        25     266.0
# 1      True  video_0001.mp4          44        59     269.0
# 2      True  video_0002.mp4           5        20     102.0
# 3      True  video_0003.mp4         160       175     238.0
# 4      True  video_0004.mp4           0        15      83.0

# %%
#get durations for videos that successfully downloaded
clip_duration_seconds = []
clip_frame_counts = []

for video in downloads_df.renamed_title:
    
    video_clip = video.replace('_', '_clip_')
    
    frames = get_num_video_frames(video_clip, clips=True)
    seconds, video_time = get_video_duration(video_clip, clips=True)
    
    clip_duration_seconds.append(seconds)
    clip_frame_counts.append(frames)

print('Done collection video clip duration info.')
# Out:
# [av1 @ 0x35919c0] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35919c0] Failed to get pixel format.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35919c0] Missing Sequence Header.
# [av1 @ 0x35d0400] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35d0400] Failed to get pixel format.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35a4f80] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35a4f80] Failed to get pixel format.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] video_get_buffer: image parameters invalid
# [av1 @ 0x35a4f80] get_buffer() failed
# [av1 @ 0x35a4f80] thread_get_buffer() failed
# [av1 @ 0x35a4f80] Failed to allocate space for current frame.
# [av1 @ 0x35a4f80] Get current frame error
# [av1 @ 0x35a4f80] video_get_buffer: image parameters invalid
# [av1 @ 0x35a4f80] get_buffer() failed
# [av1 @ 0x35a4f80] thread_get_buffer() failed
# [av1 @ 0x35a4f80] Failed to allocate space for current frame.
# [av1 @ 0x35a4f80] Get current frame error
# [av1 @ 0x35a4f80] Failed to get reference frame.
# [av1 @ 0x35a4f80] video_get_buffer: image parameters invalid
# [av1 @ 0x35a4f80] get_buffer() failed
# [av1 @ 0x35a4f80] thread_get_buffer() failed
# [av1 @ 0x35a4f80] Failed to allocate space for current frame.
# [av1 @ 0x35a4f80] Get current frame error
# [av1 @ 0x35a4f80] Failed to get reference frame.
# [av1 @ 0x35a4f80] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35a4f80] Failed to get pixel format.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] Missing Sequence Header.
# [av1 @ 0x35a4f80] video_get_buffer: image parameters invalid
# [av1 @ 0x35a4f80] get_buffer() failed
# [av1 @ 0x35a4f80] thread_get_buffer() failed
# [av1 @ 0x35a4f80] Failed to allocate space for current frame.
# [av1 @ 0x35a4f80] Get current frame error
# [av1 @ 0x35a4f80] video_get_buffer: image parameters invalid
# [av1 @ 0x35a4f80] get_buffer() failed
# [av1 @ 0x35a4f80] thread_get_buffer() failed
# [av1 @ 0x35a4f80] Failed to allocate space for current frame.
# [av1 @ 0x35a4f80] Get current frame error
# [av1 @ 0x35a4f80] Failed to get reference frame.
# [av1 @ 0x35a4f80] video_get_buffer: image parameters invalid
# [av1 @ 0x35a4f80] get_buffer() failed
# [av1 @ 0x35a4f80] thread_get_buffer() failed
# [av1 @ 0x35a4f80] Failed to allocate space for current frame.
# [av1 @ 0x35a4f80] Get current frame error
# [av1 @ 0x35a4f80] Failed to get reference frame.
# [av1 @ 0x35d0400] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35d0400] Failed to get pixel format.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35d0400] Failed to get pixel format.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35d0400] Failed to get pixel format.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] Your platform doesn't suppport hardware accelerated AV1 decoding.
# [av1 @ 0x35d0400] Failed to get pixel format.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] Missing Sequence Header.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# [av1 @ 0x35d0400] video_get_buffer: image parameters invalid
# [av1 @ 0x35d0400] get_buffer() failed
# [av1 @ 0x35d0400] thread_get_buffer() failed
# [av1 @ 0x35d0400] Failed to allocate space for current frame.
# [av1 @ 0x35d0400] Get current frame error
# [av1 @ 0x35d0400] Failed to get reference frame.
# Done collection video clip duration info.

# %%
#histogram of video clip durations in seconds
print('Mean Video Duration (seconds):   ', np.array(clip_duration_seconds).mean())
print('Median Video Duration (seconds): ', np.median(np.array(clip_duration_seconds)))
print('Max Video Duration (seconds):    ', np.array(clip_duration_seconds).max())
print('Min Video Duration (seconds):    ', np.array(clip_duration_seconds).min(), '\n')

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
plt.hist(clip_duration_seconds)
plt.xlabel('Duration(seconds)')
plt.ylabel('Count')
plt.title('Video Clip Durations in Seconds of Successful Downloads');
# Out:
# Mean Video Duration (seconds):    16.255434782608695
# Median Video Duration (seconds):  16.0
# Max Video Duration (seconds):     22
# Min Video Duration (seconds):     4

# %% [markdown]
# # Number of Frames Reported - OpenCV

# %%
#histogram of video clip frame counts reported using OpenCV CAP_PROP_FRAME_COUNT
print('Mean Num. Frames:   ', downloads_df.frames_reported.mean())
print('Median Num. Frames: ', downloads_df.frames_reported.median())
print('Max Num. Frames:    ', downloads_df.frames_reported.max())
print('Min Num. Frames:    ', downloads_df.frames_reported.min(), '\n')

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
downloads_df.frames_reported_decord.plot(kind='hist', title='Number of Frames Reported Per Video Clip - OpenCV');
plt.xlabel('Frames');
plt.ylabel('Count');
# Out:
# Mean Num. Frames:    499.85714285714283
# Median Num. Frames:  467.0
# Max Num. Frames:     1287.0
# Min Num. Frames:     42.0

# %% [markdown]
# # Number of Frames Actually Available - OpenCV

# %%
#histogram of video clip frame counts when we actually try to download frames with OpenCV
print('Mean Num. Frames:   ', downloads_df.frames_collected.mean())
print('Median Num. Frames: ', downloads_df.frames_collected.median())
print('Max Num. Frames:    ', downloads_df.frames_collected.max())
print('Min Num. Frames:    ', downloads_df.frames_collected.min(), '\n')

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
downloads_df.frames_collected.plot(kind='hist', title='Number of Frames Actually Available Per Video Clip - OpenCV');
plt.xlabel('Frames');
plt.ylabel('Count');
# Out:
# Mean Num. Frames:    438.72802197802196
# Median Num. Frames:  450.0
# Max Num. Frames:     1137.0
# Min Num. Frames:     42.0

# %% [markdown]
# # Number of Frames Available using Decord Frame Reader

# %%
#histogram of video clip frame counts when we use a library like Decord
print('Mean Num. Frames:   ', downloads_df.frames_reported_decord.mean())
print('Median Num. Frames: ', downloads_df.frames_reported_decord.median())
print('Max Num. Frames:    ', downloads_df.frames_reported_decord.max())
print('Min Num. Frames:    ', downloads_df.frames_reported_decord.min(), '\n')

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
downloads_df.frames_reported_decord.plot(kind='hist', title='Number of Frames Available Per Video Clip - Decord');
plt.xlabel('Frames');
plt.ylabel('Count');
# Out:
# Mean Num. Frames:    494.04945054945057
# Median Num. Frames:  461.0
# Max Num. Frames:     1287.0
# Min Num. Frames:     42.0

# %% [markdown]
# Final Decision is to use `Decord` as our library to extract frames from our dataset clips. We will extract `460` frames from each clip.

# %% [markdown]
# # Visualizing Dataset + Video Clips with WandB

# %%
import wandb

wandb.login()
# Out:
# True

# %%
#visualize video clips and data with wandb
wandb.init(project="whale-classification-inception", name="tables")

clip_folder = workspace_path + "/video_clips/"
downloads_df_wandb = downloads_df.copy(deep=True)

#get wandb video objects
for i, row in downloads_df.iterrows():
    video_clip = clip_folder + row['renamed_title'].replace('_', '_clip_')
    downloads_df_wandb.at[i, ('wandb_clip')] = wandb.Video(video_clip, fps=4, format="gif")

#create wandb table with all information
table = wandb.Table(dataframe=downloads_df_wandb)
wandb.log({"downloads_df": table})
wandb.finish()

#save df with wandb video clip objects 
# downloads_df_copy.to_csv('/workspace/youtube-humpback-whale-classifier/data/downloads_df_wandb.csv', index=False)
# Out:
# Tracking run with wandb version 0.12.20
# Run data is saved locally in <code>/workspace/youtube-humpback-whale-classifier/eda/wandb/run-20220701_154426-24glddpe</code>
# Syncing run <strong><a href="https://wandb.ai/etg/whale-classification-inception/runs/24glddpe" target="_blank">tables</a></strong> to <a href="https://wandb.ai/etg/whale-classification-inception" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">tables</strong>: <a href="https://wandb.ai/etg/whale-classification-inception/runs/24glddpe" target="_blank">https://wandb.ai/etg/whale-classification-inception/runs/24glddpe</a><br/>Synced 4 W&B file(s), 1 media file(s), 368 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220701_154426-24glddpe/logs</code>
